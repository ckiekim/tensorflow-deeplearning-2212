# %% [markdown]
# # Cifar-100 이미지 분류
# - Cifar-10과 동일한 모델

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
seed = 2023
np.random.seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar100
(X_train, y_train), (X_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 13s 0us/step

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
class_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'    
]

# %%
plt.figure(figsize=(10,6))
for i in range(50):
    plt.subplot(5, 10, i+1)
    plt.imshow(X_train[i])
    plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X_data
# X_train = X_train / 255.      # 실수의 기본 타입인 double(64비트)
# X_test = X_test / 255.
X_train = X_train.astype('float32') / 255.      # 32비트 float32로 변환
X_test = X_test.astype('float32') / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((50000, 100), (10000, 100))

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([ 
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(100, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 1,297,028
# Trainable params: 1,297,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile('adam', 'categorical_crossentropy', ['accuracy'])
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),    # learning rate를 epoch가 늘어날 때마다 조금씩 줄여줌
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best_model.h5'
mc = ModelCheckpoint(filepath=model_path, verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=10)
hist = model.fit(X_train, Y_train, validation_split=0.2,
                   epochs=100, batch_size=64, 
                   callbacks=[mc, es])
# Out:
# Epoch 1/100
# 619/625 [============================>.] - ETA: 0s - loss: 4.4441 - accuracy: 0.0312
# Epoch 1: val_loss improved from inf to 4.12427, saving model to best_model.h5
# 625/625 [==============================] - 14s 9ms/step - loss: 4.4417 - accuracy: 0.0316 - val_loss: 4.1243 - val_accuracy: 0.0869
# Epoch 2/100
# 621/625 [============================>.] - ETA: 0s - loss: 4.0375 - accuracy: 0.0851
# Epoch 2: val_loss improved from 4.12427 to 3.77938, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 4.0369 - accuracy: 0.0850 - val_loss: 3.7794 - val_accuracy: 0.1365
# Epoch 3/100
# 624/625 [============================>.] - ETA: 0s - loss: 3.8091 - accuracy: 0.1208
# Epoch 3: val_loss improved from 3.77938 to 3.60271, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.8087 - accuracy: 0.1208 - val_loss: 3.6027 - val_accuracy: 0.1636
# Epoch 4/100
# 623/625 [============================>.] - ETA: 0s - loss: 3.6557 - accuracy: 0.1428
# Epoch 4: val_loss improved from 3.60271 to 3.47798, saving model to best_model.h5
# 625/625 [==============================] - 5s 9ms/step - loss: 3.6561 - accuracy: 0.1426 - val_loss: 3.4780 - val_accuracy: 0.1874
# Epoch 5/100
# 623/625 [============================>.] - ETA: 0s - loss: 3.5306 - accuracy: 0.1657
# Epoch 5: val_loss improved from 3.47798 to 3.36276, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.5309 - accuracy: 0.1656 - val_loss: 3.3628 - val_accuracy: 0.2005
# Epoch 6/100
# 622/625 [============================>.] - ETA: 0s - loss: 3.4316 - accuracy: 0.1797
# Epoch 6: val_loss improved from 3.36276 to 3.27998, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.4323 - accuracy: 0.1797 - val_loss: 3.2800 - val_accuracy: 0.2195
# Epoch 7/100
# 618/625 [============================>.] - ETA: 0s - loss: 3.3450 - accuracy: 0.1966
# Epoch 7: val_loss improved from 3.27998 to 3.18937, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.3448 - accuracy: 0.1965 - val_loss: 3.1894 - val_accuracy: 0.2340
# Epoch 8/100
# 622/625 [============================>.] - ETA: 0s - loss: 3.2569 - accuracy: 0.2153
# Epoch 8: val_loss improved from 3.18937 to 3.14412, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.2572 - accuracy: 0.2151 - val_loss: 3.1441 - val_accuracy: 0.2454
# Epoch 9/100
# 623/625 [============================>.] - ETA: 0s - loss: 3.1905 - accuracy: 0.2265
# Epoch 9: val_loss improved from 3.14412 to 3.05172, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.1903 - accuracy: 0.2265 - val_loss: 3.0517 - val_accuracy: 0.2584
# Epoch 10/100
# 620/625 [============================>.] - ETA: 0s - loss: 3.1177 - accuracy: 0.2397
# Epoch 10: val_loss improved from 3.05172 to 3.00736, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.1184 - accuracy: 0.2395 - val_loss: 3.0074 - val_accuracy: 0.2705
# Epoch 11/100
# 619/625 [============================>.] - ETA: 0s - loss: 3.0540 - accuracy: 0.2548
# Epoch 11: val_loss improved from 3.00736 to 2.97681, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.0545 - accuracy: 0.2550 - val_loss: 2.9768 - val_accuracy: 0.2810
# Epoch 12/100
# 618/625 [============================>.] - ETA: 0s - loss: 3.0003 - accuracy: 0.2607
# Epoch 12: val_loss improved from 2.97681 to 2.89524, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 3.0003 - accuracy: 0.2607 - val_loss: 2.8952 - val_accuracy: 0.2945
# Epoch 13/100
# 625/625 [==============================] - ETA: 0s - loss: 2.9477 - accuracy: 0.2719
# Epoch 13: val_loss improved from 2.89524 to 2.86264, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.9477 - accuracy: 0.2719 - val_loss: 2.8626 - val_accuracy: 0.2984
# Epoch 14/100
# 619/625 [============================>.] - ETA: 0s - loss: 2.8922 - accuracy: 0.2841
# Epoch 14: val_loss improved from 2.86264 to 2.81303, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.8926 - accuracy: 0.2842 - val_loss: 2.8130 - val_accuracy: 0.3073
# Epoch 15/100
# 619/625 [============================>.] - ETA: 0s - loss: 2.8457 - accuracy: 0.2947
# Epoch 15: val_loss improved from 2.81303 to 2.76504, saving model to best_model.h5
# 625/625 [==============================] - 6s 9ms/step - loss: 2.8452 - accuracy: 0.2946 - val_loss: 2.7650 - val_accuracy: 0.3162
# Epoch 16/100
# 621/625 [============================>.] - ETA: 0s - loss: 2.7995 - accuracy: 0.3021
# Epoch 16: val_loss improved from 2.76504 to 2.72574, saving model to best_model.h5
# 625/625 [==============================] - 6s 9ms/step - loss: 2.8008 - accuracy: 0.3019 - val_loss: 2.7257 - val_accuracy: 0.3264
# Epoch 17/100
# 621/625 [============================>.] - ETA: 0s - loss: 2.7538 - accuracy: 0.3116
# Epoch 17: val_loss did not improve from 2.72574
# 625/625 [==============================] - 5s 8ms/step - loss: 2.7542 - accuracy: 0.3115 - val_loss: 2.7272 - val_accuracy: 0.3274
# Epoch 18/100
# 620/625 [============================>.] - ETA: 0s - loss: 2.7204 - accuracy: 0.3150
# Epoch 18: val_loss improved from 2.72574 to 2.65636, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.7210 - accuracy: 0.3151 - val_loss: 2.6564 - val_accuracy: 0.3398
# Epoch 19/100
# 619/625 [============================>.] - ETA: 0s - loss: 2.6791 - accuracy: 0.3295
# Epoch 19: val_loss improved from 2.65636 to 2.62879, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.6787 - accuracy: 0.3296 - val_loss: 2.6288 - val_accuracy: 0.3452
# Epoch 20/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.6370 - accuracy: 0.3365
# Epoch 20: val_loss improved from 2.62879 to 2.60033, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.6371 - accuracy: 0.3364 - val_loss: 2.6003 - val_accuracy: 0.3492
# Epoch 21/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.6035 - accuracy: 0.3418
# Epoch 21: val_loss improved from 2.60033 to 2.58222, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.6030 - accuracy: 0.3420 - val_loss: 2.5822 - val_accuracy: 0.3559
# Epoch 22/100
# 625/625 [==============================] - ETA: 0s - loss: 2.5740 - accuracy: 0.3477
# Epoch 22: val_loss improved from 2.58222 to 2.54275, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.5740 - accuracy: 0.3477 - val_loss: 2.5428 - val_accuracy: 0.3659
# Epoch 23/100
# 623/625 [============================>.] - ETA: 0s - loss: 2.5409 - accuracy: 0.3515
# Epoch 23: val_loss did not improve from 2.54275
# 625/625 [==============================] - 5s 8ms/step - loss: 2.5416 - accuracy: 0.3514 - val_loss: 2.5469 - val_accuracy: 0.3644
# Epoch 24/100
# 622/625 [============================>.] - ETA: 0s - loss: 2.5007 - accuracy: 0.3630
# Epoch 24: val_loss improved from 2.54275 to 2.50721, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.5002 - accuracy: 0.3632 - val_loss: 2.5072 - val_accuracy: 0.3706
# Epoch 25/100
# 619/625 [============================>.] - ETA: 0s - loss: 2.4769 - accuracy: 0.3678
# Epoch 25: val_loss improved from 2.50721 to 2.49072, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.4748 - accuracy: 0.3683 - val_loss: 2.4907 - val_accuracy: 0.3761
# Epoch 26/100
# 623/625 [============================>.] - ETA: 0s - loss: 2.4427 - accuracy: 0.3760
# Epoch 26: val_loss improved from 2.49072 to 2.46661, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.4428 - accuracy: 0.3761 - val_loss: 2.4666 - val_accuracy: 0.3794
# Epoch 27/100
# 618/625 [============================>.] - ETA: 0s - loss: 2.4212 - accuracy: 0.3811
# Epoch 27: val_loss improved from 2.46661 to 2.46180, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.4212 - accuracy: 0.3808 - val_loss: 2.4618 - val_accuracy: 0.3799
# Epoch 28/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.3898 - accuracy: 0.3858
# Epoch 28: val_loss improved from 2.46180 to 2.42140, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.3894 - accuracy: 0.3858 - val_loss: 2.4214 - val_accuracy: 0.3893
# Epoch 29/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.3496 - accuracy: 0.3964
# Epoch 29: val_loss did not improve from 2.42140
# 625/625 [==============================] - 5s 8ms/step - loss: 2.3495 - accuracy: 0.3964 - val_loss: 2.4222 - val_accuracy: 0.3881
# Epoch 30/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.3352 - accuracy: 0.3994
# Epoch 30: val_loss improved from 2.42140 to 2.38561, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.3354 - accuracy: 0.3993 - val_loss: 2.3856 - val_accuracy: 0.3977
# Epoch 31/100
# 620/625 [============================>.] - ETA: 0s - loss: 2.3128 - accuracy: 0.4043
# Epoch 31: val_loss did not improve from 2.38561
# 625/625 [==============================] - 5s 8ms/step - loss: 2.3126 - accuracy: 0.4042 - val_loss: 2.4076 - val_accuracy: 0.3891
# Epoch 32/100
# 621/625 [============================>.] - ETA: 0s - loss: 2.2811 - accuracy: 0.4092
# Epoch 32: val_loss improved from 2.38561 to 2.35383, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.2811 - accuracy: 0.4094 - val_loss: 2.3538 - val_accuracy: 0.4040
# Epoch 33/100
# 625/625 [==============================] - ETA: 0s - loss: 2.2595 - accuracy: 0.4121
# Epoch 33: val_loss improved from 2.35383 to 2.34497, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.2595 - accuracy: 0.4121 - val_loss: 2.3450 - val_accuracy: 0.4025
# Epoch 34/100
# 623/625 [============================>.] - ETA: 0s - loss: 2.2358 - accuracy: 0.4193
# Epoch 34: val_loss improved from 2.34497 to 2.31886, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.2355 - accuracy: 0.4195 - val_loss: 2.3189 - val_accuracy: 0.4117
# Epoch 35/100
# 620/625 [============================>.] - ETA: 0s - loss: 2.2194 - accuracy: 0.4221
# Epoch 35: val_loss did not improve from 2.31886
# 625/625 [==============================] - 5s 8ms/step - loss: 2.2193 - accuracy: 0.4220 - val_loss: 2.3201 - val_accuracy: 0.4138
# Epoch 36/100
# 625/625 [==============================] - ETA: 0s - loss: 2.1950 - accuracy: 0.4292
# Epoch 36: val_loss did not improve from 2.31886
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1950 - accuracy: 0.4292 - val_loss: 2.3286 - val_accuracy: 0.4083
# Epoch 37/100
# 618/625 [============================>.] - ETA: 0s - loss: 2.1699 - accuracy: 0.4342
# Epoch 37: val_loss improved from 2.31886 to 2.30772, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1705 - accuracy: 0.4339 - val_loss: 2.3077 - val_accuracy: 0.4144
# Epoch 38/100
# 621/625 [============================>.] - ETA: 0s - loss: 2.1515 - accuracy: 0.4416
# Epoch 38: val_loss improved from 2.30772 to 2.27982, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1522 - accuracy: 0.4415 - val_loss: 2.2798 - val_accuracy: 0.4225
# Epoch 39/100
# 620/625 [============================>.] - ETA: 0s - loss: 2.1351 - accuracy: 0.4408
# Epoch 39: val_loss improved from 2.27982 to 2.27008, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1346 - accuracy: 0.4411 - val_loss: 2.2701 - val_accuracy: 0.4210
# Epoch 40/100
# 622/625 [============================>.] - ETA: 0s - loss: 2.1190 - accuracy: 0.4453
# Epoch 40: val_loss improved from 2.27008 to 2.25383, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1190 - accuracy: 0.4453 - val_loss: 2.2538 - val_accuracy: 0.4257
# Epoch 41/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.0993 - accuracy: 0.4479
# Epoch 41: val_loss did not improve from 2.25383
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0994 - accuracy: 0.4479 - val_loss: 2.2662 - val_accuracy: 0.4177
# Epoch 42/100
# 625/625 [==============================] - ETA: 0s - loss: 2.0814 - accuracy: 0.4516
# Epoch 42: val_loss did not improve from 2.25383
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0814 - accuracy: 0.4516 - val_loss: 2.2792 - val_accuracy: 0.4229
# Epoch 43/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.0674 - accuracy: 0.4559
# Epoch 43: val_loss improved from 2.25383 to 2.23406, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0678 - accuracy: 0.4557 - val_loss: 2.2341 - val_accuracy: 0.4310
# Epoch 44/100
# 619/625 [============================>.] - ETA: 0s - loss: 2.0483 - accuracy: 0.4616
# Epoch 44: val_loss improved from 2.23406 to 2.23136, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0478 - accuracy: 0.4618 - val_loss: 2.2314 - val_accuracy: 0.4310
# Epoch 45/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.0431 - accuracy: 0.4591
# Epoch 45: val_loss improved from 2.23136 to 2.22897, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0427 - accuracy: 0.4592 - val_loss: 2.2290 - val_accuracy: 0.4334
# Epoch 46/100
# 623/625 [============================>.] - ETA: 0s - loss: 2.0184 - accuracy: 0.4659
# Epoch 46: val_loss did not improve from 2.22897
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0187 - accuracy: 0.4660 - val_loss: 2.2388 - val_accuracy: 0.4291
# Epoch 47/100
# 622/625 [============================>.] - ETA: 0s - loss: 2.0083 - accuracy: 0.4736
# Epoch 47: val_loss improved from 2.22897 to 2.20603, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0083 - accuracy: 0.4737 - val_loss: 2.2060 - val_accuracy: 0.4362
# Epoch 48/100
# 622/625 [============================>.] - ETA: 0s - loss: 1.9929 - accuracy: 0.4737
# Epoch 48: val_loss did not improve from 2.20603
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9923 - accuracy: 0.4737 - val_loss: 2.2246 - val_accuracy: 0.4325
# Epoch 49/100
# 620/625 [============================>.] - ETA: 0s - loss: 1.9802 - accuracy: 0.4782
# Epoch 49: val_loss improved from 2.20603 to 2.18464, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9813 - accuracy: 0.4778 - val_loss: 2.1846 - val_accuracy: 0.4433
# Epoch 50/100
# 623/625 [============================>.] - ETA: 0s - loss: 1.9618 - accuracy: 0.4787
# Epoch 50: val_loss did not improve from 2.18464
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9621 - accuracy: 0.4785 - val_loss: 2.1968 - val_accuracy: 0.4389
# Epoch 51/100
# 621/625 [============================>.] - ETA: 0s - loss: 1.9530 - accuracy: 0.4824
# Epoch 51: val_loss improved from 2.18464 to 2.18070, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9523 - accuracy: 0.4825 - val_loss: 2.1807 - val_accuracy: 0.4468
# Epoch 52/100
# 620/625 [============================>.] - ETA: 0s - loss: 1.9495 - accuracy: 0.4834
# Epoch 52: val_loss improved from 2.18070 to 2.17580, saving model to best_model.h5
# 625/625 [==============================] - 6s 10ms/step - loss: 1.9508 - accuracy: 0.4836 - val_loss: 2.1758 - val_accuracy: 0.4453
# Epoch 53/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.9344 - accuracy: 0.4819
# Epoch 53: val_loss did not improve from 2.17580
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9346 - accuracy: 0.4818 - val_loss: 2.1957 - val_accuracy: 0.4429
# Epoch 54/100
# 621/625 [============================>.] - ETA: 0s - loss: 1.9250 - accuracy: 0.4861
# Epoch 54: val_loss did not improve from 2.17580
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9249 - accuracy: 0.4863 - val_loss: 2.1766 - val_accuracy: 0.4469
# Epoch 55/100
# 625/625 [==============================] - ETA: 0s - loss: 1.9167 - accuracy: 0.4917
# Epoch 55: val_loss improved from 2.17580 to 2.17207, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9167 - accuracy: 0.4917 - val_loss: 2.1721 - val_accuracy: 0.4495
# Epoch 56/100
# 619/625 [============================>.] - ETA: 0s - loss: 1.9037 - accuracy: 0.4931
# Epoch 56: val_loss did not improve from 2.17207
# 625/625 [==============================] - 5s 8ms/step - loss: 1.9018 - accuracy: 0.4937 - val_loss: 2.1784 - val_accuracy: 0.4425
# Epoch 57/100
# 623/625 [============================>.] - ETA: 0s - loss: 1.8889 - accuracy: 0.4981
# Epoch 57: val_loss improved from 2.17207 to 2.16609, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8886 - accuracy: 0.4982 - val_loss: 2.1661 - val_accuracy: 0.4488
# Epoch 58/100
# 625/625 [==============================] - ETA: 0s - loss: 1.8972 - accuracy: 0.4944
# Epoch 58: val_loss did not improve from 2.16609
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8972 - accuracy: 0.4944 - val_loss: 2.1783 - val_accuracy: 0.4492
# Epoch 59/100
# 622/625 [============================>.] - ETA: 0s - loss: 1.8800 - accuracy: 0.5008
# Epoch 59: val_loss did not improve from 2.16609
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8806 - accuracy: 0.5006 - val_loss: 2.1868 - val_accuracy: 0.4478
# Epoch 60/100
# 620/625 [============================>.] - ETA: 0s - loss: 1.8755 - accuracy: 0.5023
# Epoch 60: val_loss did not improve from 2.16609
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8738 - accuracy: 0.5027 - val_loss: 2.1855 - val_accuracy: 0.4530
# Epoch 61/100
# 619/625 [============================>.] - ETA: 0s - loss: 1.8572 - accuracy: 0.5048
# Epoch 61: val_loss improved from 2.16609 to 2.15276, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8569 - accuracy: 0.5052 - val_loss: 2.1528 - val_accuracy: 0.4548
# Epoch 62/100
# 622/625 [============================>.] - ETA: 0s - loss: 1.8500 - accuracy: 0.5075
# Epoch 62: val_loss improved from 2.15276 to 2.13542, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8513 - accuracy: 0.5073 - val_loss: 2.1354 - val_accuracy: 0.4519
# Epoch 63/100
# 619/625 [============================>.] - ETA: 0s - loss: 1.8409 - accuracy: 0.5097
# Epoch 63: val_loss improved from 2.13542 to 2.12375, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8409 - accuracy: 0.5098 - val_loss: 2.1237 - val_accuracy: 0.4647
# Epoch 64/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.8454 - accuracy: 0.5113
# Epoch 64: val_loss did not improve from 2.12375
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8452 - accuracy: 0.5114 - val_loss: 2.1330 - val_accuracy: 0.4576
# Epoch 65/100
# 619/625 [============================>.] - ETA: 0s - loss: 1.8287 - accuracy: 0.5132
# Epoch 65: val_loss did not improve from 2.12375
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8281 - accuracy: 0.5134 - val_loss: 2.1631 - val_accuracy: 0.4511
# Epoch 66/100
# 620/625 [============================>.] - ETA: 0s - loss: 1.8241 - accuracy: 0.5154
# Epoch 66: val_loss did not improve from 2.12375
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8238 - accuracy: 0.5152 - val_loss: 2.1862 - val_accuracy: 0.4547
# Epoch 67/100
# 621/625 [============================>.] - ETA: 0s - loss: 1.8208 - accuracy: 0.5144
# Epoch 67: val_loss did not improve from 2.12375
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8216 - accuracy: 0.5142 - val_loss: 2.1516 - val_accuracy: 0.4619
# Epoch 68/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.8155 - accuracy: 0.5165
# Epoch 68: val_loss did not improve from 2.12375
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8152 - accuracy: 0.5165 - val_loss: 2.1326 - val_accuracy: 0.4661
# Epoch 69/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.8108 - accuracy: 0.5195
# Epoch 69: val_loss did not improve from 2.12375
# 625/625 [==============================] - 5s 8ms/step - loss: 1.8110 - accuracy: 0.5194 - val_loss: 2.1334 - val_accuracy: 0.4619
# Epoch 70/100
# 619/625 [============================>.] - ETA: 0s - loss: 1.7969 - accuracy: 0.5204
# Epoch 70: val_loss improved from 2.12375 to 2.11938, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7984 - accuracy: 0.5197 - val_loss: 2.1194 - val_accuracy: 0.4628
# Epoch 71/100
# 622/625 [============================>.] - ETA: 0s - loss: 1.7949 - accuracy: 0.5219
# Epoch 71: val_loss did not improve from 2.11938
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7953 - accuracy: 0.5217 - val_loss: 2.1367 - val_accuracy: 0.4620
# Epoch 72/100
# 620/625 [============================>.] - ETA: 0s - loss: 1.7926 - accuracy: 0.5255
# Epoch 72: val_loss did not improve from 2.11938
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7918 - accuracy: 0.5257 - val_loss: 2.1711 - val_accuracy: 0.4607
# Epoch 73/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.7896 - accuracy: 0.5217
# Epoch 73: val_loss improved from 2.11938 to 2.09425, saving model to best_model.h5
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7894 - accuracy: 0.5218 - val_loss: 2.0943 - val_accuracy: 0.4690
# Epoch 74/100
# 622/625 [============================>.] - ETA: 0s - loss: 1.7861 - accuracy: 0.5250
# Epoch 74: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7864 - accuracy: 0.5249 - val_loss: 2.1704 - val_accuracy: 0.4628
# Epoch 75/100
# 625/625 [==============================] - ETA: 0s - loss: 1.7684 - accuracy: 0.5293
# Epoch 75: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7684 - accuracy: 0.5293 - val_loss: 2.1112 - val_accuracy: 0.4649
# Epoch 76/100
# 618/625 [============================>.] - ETA: 0s - loss: 1.7779 - accuracy: 0.5271
# Epoch 76: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7791 - accuracy: 0.5267 - val_loss: 2.1095 - val_accuracy: 0.4628
# Epoch 77/100
# 619/625 [============================>.] - ETA: 0s - loss: 1.7711 - accuracy: 0.5324
# Epoch 77: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7712 - accuracy: 0.5324 - val_loss: 2.1494 - val_accuracy: 0.4637
# Epoch 78/100
# 622/625 [============================>.] - ETA: 0s - loss: 1.7743 - accuracy: 0.5301
# Epoch 78: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7734 - accuracy: 0.5302 - val_loss: 2.1269 - val_accuracy: 0.4684
# Epoch 79/100
# 621/625 [============================>.] - ETA: 0s - loss: 1.7531 - accuracy: 0.5354
# Epoch 79: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7541 - accuracy: 0.5353 - val_loss: 2.0980 - val_accuracy: 0.4673
# Epoch 80/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.7589 - accuracy: 0.5372
# Epoch 80: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7589 - accuracy: 0.5372 - val_loss: 2.1184 - val_accuracy: 0.4695
# Epoch 81/100
# 625/625 [==============================] - ETA: 0s - loss: 1.7533 - accuracy: 0.5359
# Epoch 81: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7533 - accuracy: 0.5359 - val_loss: 2.1398 - val_accuracy: 0.4675
# Epoch 82/100
# 625/625 [==============================] - ETA: 0s - loss: 1.7556 - accuracy: 0.5353
# Epoch 82: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7556 - accuracy: 0.5353 - val_loss: 2.0992 - val_accuracy: 0.4713
# Epoch 83/100
# 623/625 [============================>.] - ETA: 0s - loss: 1.7453 - accuracy: 0.5400
# Epoch 83: val_loss did not improve from 2.09425
# 625/625 [==============================] - 5s 8ms/step - loss: 1.7454 - accuracy: 0.5400 - val_loss: 2.1335 - val_accuracy: 0.4688

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 2.0828 - accuracy: 0.4701
# [2.082758903503418, 0.4700999855995178]

# %% [markdown]
# - 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid()
plt.xlabel('Epoch')
plt.show()
